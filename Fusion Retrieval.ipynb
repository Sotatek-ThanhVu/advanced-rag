# %% [markdown]
# # Setup

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

connection_string = os.getenv('CONNECTION_STRING')
openai_api_key = os.getenv('OPENAI_API_KEY')
gemini_api_key = os.getenv('GOOGLE_API_KEY')

# %% [markdown]
# # Define global context

# %%
from llama_index import ServiceContext, set_global_service_context
from llama_index.callbacks import CallbackManager, LlamaDebugHandler
from llama_index.embeddings import GeminiEmbedding
from llama_index.llms import OpenAI

llm = OpenAI(model='gpt-3.5-turbo-1106', temperature=0.0, api_key=openai_api_key)
embed_model = GeminiEmbedding(api_key=gemini_api_key)
callback_manager = CallbackManager([LlamaDebugHandler(print_trace_on_end=True)])

service_context = ServiceContext.from_defaults(
    llm=llm, embed_model=embed_model, callback_manager=callback_manager
)

set_global_service_context(service_context)

# %% [markdown]
# # Connect to storage

# %%
from sqlalchemy import make_url
from llama_index.vector_stores.postgres import PGVectorStore

uri = make_url(connection_string)
vector_store = PGVectorStore.from_params(
    host=uri.host,
    port=str(uri.port),
    database=uri.database,
    user=uri.username,
    password=uri.password,
    embed_dim=768, # REMEMBER TO CHANGE THIS TO 1536 if using OpenAI Embedding Model
)

# %% [markdown]
# # Create retrievers

# %%
from llama_index import VectorStoreIndex

index = VectorStoreIndex.from_vector_store(vector_store=vector_store)
similarity_top_k = 6
# Out:
# **********
# Trace: index_construction
# **********

# %% [markdown]
# ## Base retriever

# %%
retriever = index.as_retriever(
    similarity_top_k=similarity_top_k,
    vector_store_kwargs={
        'ivfflat_probes': 10,  # higher is better for recall, lower is better for speed. Default = 1
        'hnsw_ef_search': 300, # Specify the size of the dynamic candidate list for search. Default = 40
    },
)

# %% [markdown]
# ## Recursive retriever

# %%
from llama_index.retrievers import RecursiveRetriever

recursive_retriever = RecursiveRetriever(
    'vector', retriever_dict={'vector': retriever}, verbose=True
)

# %% [markdown]
# # Fusion Retriver

# %% [markdown]
# ## Generate new queries

# %%
from typing import List

from llama_index import PromptTemplate
from llama_index.llms import LLM

query_gen_prompt_template = """
You are a helpful assistant that generates multiple search queries based on a single input query.
Generate {num_queries} search queries, one on each line related to the following input query:
Query: {query}
Queries:
"""

# Should I using RAG to generate new queries based on those information?
# To avoid ambiguous queries?

def generate_queries(llm: LLM, query: str, num_queries: int = 4) -> List[str]:
    query_gen_prompt = PromptTemplate(query_gen_prompt_template)
    prompt = query_gen_prompt.format(num_queries=num_queries, query=query)
    response = llm.complete(prompt)
    queries = response.text.split('\n')

    return queries

# %%
queries = generate_queries(llm, "Hawaii conferences")

# %% [markdown]
# ## Run queries

# %%
from typing import Dict, List, Tuple

from llama_index.retrievers import BaseRetriever
from llama_index.schema import NodeWithScore

def run_queries(queries: List[str], retrievers: List[BaseRetriever]) -> Dict[Tuple[str, int], List[NodeWithScore]]:
    results = []
    for query in queries:
        for retriever in retrievers:
            results.append(retriever.retrieve(query)) # This one should be promisable

    results_dict: Dict[Tuple[str, int], List[NodeWithScore]] = {}
    for i, (query, query_result) in enumerate(zip(queries, results)):
        results_dict[(query, i)] = query_result

    return results_dict

# %%
run_queries(queries, [retriever, recursive_retriever])
# Out:
# Retrieving with query id None: 1. Best Hawaii conferences 2022
# Retrieving text node: id 64
# created_at 2024-01-04 10:26:21.324
# updated_at 2024-01-05 02:33:01.038
# name HN
# start_date 2024-01-05 00:26:12.846
# end_date 2024-01-05 00:26:13.998
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors HN
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 14
# event_remark
# destination_id 27
# Retrieving with query id None: 2. Hawaii conference venues
# Retrieving text node: id 64
# created_at 2024-01-04 10:26:21.324
# updated_at 2024-01-05 02:33:01.038
# name HN
# start_date 2024-01-05 00:26:12.846
# end_date 2024-01-05 00:26:13.998
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors HN
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 14
# event_remark
# destination_id 27
# Retrieving with query id None: 3. Hawaii conference schedule
# Retrieving text node: id 64
# created_at 2024-01-04 10:26:21.324
# updated_at 2024-01-05 02:33:01.038
# name HN
# start_date 2024-01-05 00:26:12.846
# end_date 2024-01-05 00:26:13.998
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors HN
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 14
# event_remark
# destination_id 27
# Retrieving with query id None: 4. Hawaii conference registration fees
# Retrieving text node: id 64
# created_at 2024-01-04 10:26:21.324
# updated_at 2024-01-05 02:33:01.038
# name HN
# start_date 2024-01-05 00:26:12.846
# end_date 2024-01-05 00:26:13.998
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors HN
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 14
# event_remark
# destination_id 27
# {('1. Best Hawaii conferences 2022',
#   0): [NodeWithScore(node=TextNode(id_='7c0b09a9-e0b3-41dc-94d8-532ce7ae1344', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='fb48f079-a169-4ea9-9108-382e6cbd3761', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='4d638fd299a52438470f6946a6b9169319c14aaee8e017650008e236757150e9'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='44967a0d-f90d-4a02-9220-377758c68bb9', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='8b61eebcc4204893d123fc3ef92433ab455a240b9def81f867f92b4a96965172')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text='id 64\ncreated_at 2024-01-04 10:26:21.324\nupdated_at 2024-01-05 02:33:01.038\nname HN\nstart_date 2024-01-05 00:26:12.846\nend_date 2024-01-05 00:26:13.998\ncme_provider HN\nvenue Hanoi, Vietnam\nlat 21.030384\nlng 105.85531\ndescription \ninstructors HN\ncme_credit \nself_assessment_module \ncrawl_url \ncme_course_webpage_url \nbackground_image \nprice \nevent_type On-site meeting\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field \npoints 14\nevent_remark \ndestination_id 27', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.7062399746627697)],
#  ('2. Hawaii conference venues',
#   1): [NodeWithScore(node=TextNode(id_='7c0b09a9-e0b3-41dc-94d8-532ce7ae1344', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='fb48f079-a169-4ea9-9108-382e6cbd3761', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='4d638fd299a52438470f6946a6b9169319c14aaee8e017650008e236757150e9'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='44967a0d-f90d-4a02-9220-377758c68bb9', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='8b61eebcc4204893d123fc3ef92433ab455a240b9def81f867f92b4a96965172')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text='id 64\ncreated_at 2024-01-04 10:26:21.324\nupdated_at 2024-01-05 02:33:01.038\nname HN\nstart_date 2024-01-05 00:26:12.846\nend_date 2024-01-05 00:26:13.998\ncme_provider HN\nvenue Hanoi, Vietnam\nlat 21.030384\nlng 105.85531\ndescription \ninstructors HN\ncme_credit \nself_assessment_module \ncrawl_url \ncme_course_webpage_url \nbackground_image \nprice \nevent_type On-site meeting\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field \npoints 14\nevent_remark \ndestination_id 27', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.7062399746627697)],
#  ('3. Hawaii conference schedule',
#   2): [NodeWithScore(node=TextNode(id_='7c0b09a9-e0b3-41dc-94d8-532ce7ae1344', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='fb48f079-a169-4ea9-9108-382e6cbd3761', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='4d638fd299a52438470f6946a6b9169319c14aaee8e017650008e236757150e9'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='44967a0d-f90d-4a02-9220-377758c68bb9', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='8b61eebcc4204893d123fc3ef92433ab455a240b9def81f867f92b4a96965172')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text='id 64\ncreated_at 2024-01-04 10:26:21.324\nupdated_at 2024-01-05 02:33:01.038\nname HN\nstart_date 2024-01-05 00:26:12.846\nend_date 2024-01-05 00:26:13.998\ncme_provider HN\nvenue Hanoi, Vietnam\nlat 21.030384\nlng 105.85531\ndescription \ninstructors HN\ncme_credit \nself_assessment_module \ncrawl_url \ncme_course_webpage_url \nbackground_image \nprice \nevent_type On-site meeting\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field \npoints 14\nevent_remark \ndestination_id 27', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.7014937885710844)],
#  ('4. Hawaii conference registration fees',
#   3): [NodeWithScore(node=TextNode(id_='7c0b09a9-e0b3-41dc-94d8-532ce7ae1344', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='fb48f079-a169-4ea9-9108-382e6cbd3761', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='4d638fd299a52438470f6946a6b9169319c14aaee8e017650008e236757150e9'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='44967a0d-f90d-4a02-9220-377758c68bb9', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='8b61eebcc4204893d123fc3ef92433ab455a240b9def81f867f92b4a96965172')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text='id 64\ncreated_at 2024-01-04 10:26:21.324\nupdated_at 2024-01-05 02:33:01.038\nname HN\nstart_date 2024-01-05 00:26:12.846\nend_date 2024-01-05 00:26:13.998\ncme_provider HN\nvenue Hanoi, Vietnam\nlat 21.030384\nlng 105.85531\ndescription \ninstructors HN\ncme_credit \nself_assessment_module \ncrawl_url \ncme_course_webpage_url \nbackground_image \nprice \nevent_type On-site meeting\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field \npoints 14\nevent_remark \ndestination_id 27', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.7014937885710844)]}

# %% [markdown]
# ## Fuse results

# %%
from typing import Dict, List, Tuple

from llama_index.schema import NodeWithScore

# k: control the impact of outlier rankings
def fuse_results(
    results_dict: Dict[Tuple[str, int], List[NodeWithScore]], similarity_top_k: int, k: float = 60.0
) -> List[NodeWithScore]:
    fused_scores: Dict[str, float] = {}
    text_to_node: Dict[str, NodeWithScore] = {}

    for node_with_scores in results_dict.values():
        for rank, node_with_score in enumerate(sorted(node_with_scores, key=lambda x: x.score or 0.0, reverse=True)):
            text = node_with_score.get_content()
            text_to_node[text] = node_with_score

            if text not in fused_scores:
                fused_scores[text] = 0.0
            fused_scores[text] = 1.0 / (rank + k)

    reranked_results = dict(sorted(fused_scores.items(), key=lambda x: x[1], reverse=True))

    reranked_nodes: List[NodeWithScore] = []
    for text, score in reranked_results.items():
        reranked_nodes.append(text_to_node[text])
        reranked_nodes[-1].score = score

    return reranked_nodes[:similarity_top_k]

# %% [markdown]
# ## Fusion Retriever

# %%
from typing import List, Optional

from llama_index import QueryBundle
from llama_index.callbacks import CallbackManager
from llama_index.llms import LLM
from llama_index.retrievers import BaseRetriever
from llama_index.schema import NodeWithScore

class FusionRetriever(BaseRetriever):
    def __init__(
        self,
        llm: LLM,
        retrievers: List[BaseRetriever],
        similarity_top_k: int,
        k: float = 60.0,
        num_queries: int = 4,
        callback_manager: Optional[CallbackManager] = None,
    ) -> None:
        self._callback_manager = callback_manager
        self._llm = llm
        self._num_queries = num_queries
        self._k = k
        self._similarity_top_k = similarity_top_k
        self._retrievers = retrievers
        super().__init__(callback_manager)

    def _retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
        queries = generate_queries(llm, query_bundle, self._num_queries)
        results = run_queries(queries, self._retrievers)
        fused_results = fuse_results(results, self._similarity_top_k, self._k)

        return fused_results

# %% [markdown]
# # MAIN

# %%
fusion_retriever = FusionRetriever(
    llm=llm,
    retrievers=[retriever, recursive_retriever],
    similarity_top_k=similarity_top_k
)

# %%
from llama_index import get_response_synthesizer
from llama_index.query_engine import RetrieverQueryEngine
from llama_index.response_synthesizers import ResponseMode

query_engine = RetrieverQueryEngine.from_args(
    retriever=fusion_retriever,
    response_synthesizer=get_response_synthesizer(
        callback_manager=callback_manager,
        streaming=True,
        verbose=True,
    ),
    response_mode=ResponseMode.NO_TEXT,
    streaming=True,
)

# %%
query = "Radiology conference in exotic places, >3 days and at least 20 points. Return in array of id only."

# %%
response = query_engine.query(query)
# Out:
# Retrieving with query id None: 1. "Radiology conference exotic locations duration >3 days"
# Retrieving text node: id 29
# created_at 2024-01-04 09:38:10.401
# updated_at 2024-01-05 03:34:02.707
# name 2023 Top 3 Differentials in Radiology
# start_date 2023-04-24 00:00:00.000
# end_date 2023-04-28 00:00:00.000
# cme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States
# venue The Wigwam, 300 East Wigwam Blvd, Litchfield Park, Arizona (AZ), United States
# lat 33.495228
# lng -112.355125
# description The 2023 “Top 3” Conference, sponsored by the American Osteopathic College of Radiology, is intended for practicing radiologists and radiology trainees as a comprehensive and practical case-based radiology review.  All subspecialties and imaging modalities will be covered with lectures divided into the following sections: neuroimaging, musculoskeletal imaging, gastrointestinal imaging, genitourinary imaging, ultrasound imaging, cardiothoracic imaging, pediatric imaging, breast imaging, vascular & interventional radiology, and nuclear medicine.  Lectures are provided by a distinguished group of faculty with a wealth of clinical and teaching experience, each covering the key clinical and imaging findings for differentials within common imaging gamuts, as well as characteristic “Aunt Minnie” cases.  Our goal is to provide attendees with a comprehensive gamut-based approach to image interpretation with helpful pearls to help distinguish between entities on a list of differential diagnoses.
# Visit the CME Course Webpage ›
# View the Course Brochure ›
# instructors William O’Brien, DO; Christine Glastonbury, MBBS; Jennifer McCarty, MD; Rocky Saenz, DO; Shaun Wahab, MD; Ram Chadalavada, MD; John Lichtenberger, MD; Carl Merrow, MD; Christine Chung, MD; Lori Strachowski, MD; Rifat Wahab, DO; Timothy McKnight, DO
# cme_credit Physicians:  30 Hours
# self_assessment_module Yes
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24569
# cme_course_webpage_url https://www.aocr.org/events/EventDetails.aspx?id=1616453
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 7
# Retrieving text node: id 64
# created_at 2024-01-04 10:26:21.324
# updated_at 2024-01-05 02:33:01.038
# name HN
# start_date 2024-01-05 00:26:12.846
# end_date 2024-01-05 00:26:13.998
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors HN
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 14
# event_remark
# destination_id 27
# Retrieving text node: id 66
# created_at 2024-01-04 10:33:43.029
# updated_at 2024-01-05 02:33:02.300
# name HN
# start_date 2024-01-04 17:33:30.359
# end_date 2024-01-05 17:33:31.626
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 15
# event_remark
# destination_id 27
# Retrieving text node: id 22
# created_at 2024-01-04 09:38:10.271
# updated_at 2024-01-05 03:34:02.671
# name Advanced Imaging In the Islands
# start_date 2024-02-20 00:00:00.000
# end_date 2024-02-23 00:00:00.000
# cme_provider Duke University Department of Radiology ›, Debbie Griffin, Room 1531B Duke University Hospital, 2301 Erwin Road, Durham, North Carolina (NC)  27710, United States
# venue The Ritz-Carlton, Grand Cayman, PO Box 32348 KY1-1209, Seven Mile Beach, Grand Cayman, Cayman Islands
# lat 26.8917
# lng -80.08965
# description This course has been designed for the
# radiologist interested in gaining a greater
# understanding of advances in diagnostic
# imaging, specifically implementing a
# multidisciplinary approach to education
# via a combination of experts from
# Duke’s Divisions of Abdominal Imaging
# Breast Imaging, Cardiothoracic Imaging,
# Neuroradiology, Musculoskeletal Imaging
# and Vascular/Interventional Radiology.
# Visit the CME Course Webpage ›
# View the Course Brochure ›
# instructors Rajan Gupta, MD
# Professor
# Travis Henry, MD
# Professor
# Lisa Ho, MD
# Associate Professor
# Peter Kranz, MD
# Associate Professor
# Paul Suhocki, MD
# Associate Professor
# Leah Waldman, MD
# Assistant Professor
# cme_credit Physicians:  20 Hours
# Physician Assistants:  20 Hours
# self_assessment_module No
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24688
# cme_course_webpage_url https://radiology.duke.edu/education/continuing-medical-education/advanced-imaging-islands-feb-20-23-2024
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 5
# Retrieving text node: id 59
# created_at 2024-01-04 09:38:12.491
# updated_at 2024-01-05 03:33:42.889
# name Top 3 Differentials in Radiology
# start_date 2021-11-17 00:00:00.000
# end_date 2024-08-20 00:00:00.000
# cme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States
# venue
# lat None
# lng None
# description This program is intended for practicing radiologists and radiology trainees as a comprehensive and practical case-based radiology review. All subspecialties and imaging modalities will be covered with lectures divided into the following sections: neuroimaging, musculoskeletal imaging, gastrointestinal imaging, genitourinary imaging, ultrasound imaging, cardiothoracic imaging, pediatric imaging, breast imaging, vascular & interventional radiology, and nuclear medicine. Lectures are provided by a distinguished group of faculty with a wealth of clinical and teaching experience, each covering the key clinical and imaging findings for differentials within common imaging gamuts, as well as characteristic “Aunt Minnie” cases. Our goal is to provide attendees with a comprehensive gamut-based approach to image interpretation with helpful pearls to help distinguish between entities on a list of differential diagnoses.
# Objectives:
# Formulate gamut-based differential diagnoses for key imaging findings across all radiology subspecialties and imaging modalities.
# Distinguish amongst differential diagnoses based upon characteristic imaging findings.
# Recognize & identify diagnoses with classic imaging findings, in which there is no differential diagnosis.
# Implement and optimize imaging modalities and protocols to improve diagnostic accuracy.
# Recognize appropriate indications for image-guided interventional procedures, as well as management of potential complications.
# Visit the CME Course Webpage ›
# instructors William T. O'Brien, Sr. DO, FAOCR, Program Chair
# Christopher Cerniglia, DO, ME, FAOCR
# Seetharam Chadalavada, MD, MS
# Christine M. Glastonbury, MBBS
# Grant E. Lattin, Jr., MD
# John P. Lichtenberger III, MD
# Jennifer McCarty, MD
# Timothy McKnight, DO
# Arnold Carlson Merrow, Jr., MD, FAAP
# Rocky C. Saenz, DO, FAOCR
# Lori M. Strachowski, MD
# Rifat A. Wahab, DO
# Lily Wang, MBBS
# cme_credit Physicians:  28 Hours
# self_assessment_module Yes
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24214
# cme_course_webpage_url http://aocr.mycrowdwisdom.com/diweb/catalog/item/id/6499083/q/n=4&c=476
# background_image
# price
# event_type Courses
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id None
# Retrieving text node: id 27
# created_at 2024-01-04 09:38:10.367
# updated_at 2024-01-05 03:34:02.685
# name Mayo Clinic Neuroradiology: Practice to Innovation
# start_date 2025-11-10 00:00:00.000
# end_date 2025-11-14 00:00:00.000
# cme_provider Mayo Clinic Department of Radiology ›, CME Office, 200 1st Street SW, Mayo 2-48W, Rochester, Minnesota (MN)  55905, United States
# venue Grand Hyatt Kauai Resort and Spa, 1571 Poipu Road, Koloa, Hawaii (HI), United States
# lat 21.876104
# lng -159.43938
# description Neuroradiology: Practice to Innovation is intended to provide a practical discussion and review of common diseases involving the brain, head/neck, and spine. It will also provide an overview of common imaging strategies, as well as an update in new trends, relevant techniques, and applications in diagnostic and/or therapeutic neuroradiology.
# Visit the CME Course Webpage ›
# instructors Course Directors:
# Christopher H. Hunt, M.D.
# Felix E. Diehn, M.D.
# Timothy J. Kaufmann, M.D.
# cme_credit Physicians:  Credit Available
# self_assessment_module No
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24356
# cme_course_webpage_url https://radiologyeducation.mayo.edu/store/neuroradiology-practice-to-innovation-2025
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 12
# Retrieving with query id None: 2. "Radiology conference points requirement >=20"
# Retrieving text node: id 29
# created_at 2024-01-04 09:38:10.401
# updated_at 2024-01-05 03:34:02.707
# name 2023 Top 3 Differentials in Radiology
# start_date 2023-04-24 00:00:00.000
# end_date 2023-04-28 00:00:00.000
# cme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States
# venue The Wigwam, 300 East Wigwam Blvd, Litchfield Park, Arizona (AZ), United States
# lat 33.495228
# lng -112.355125
# description The 2023 “Top 3” Conference, sponsored by the American Osteopathic College of Radiology, is intended for practicing radiologists and radiology trainees as a comprehensive and practical case-based radiology review.  All subspecialties and imaging modalities will be covered with lectures divided into the following sections: neuroimaging, musculoskeletal imaging, gastrointestinal imaging, genitourinary imaging, ultrasound imaging, cardiothoracic imaging, pediatric imaging, breast imaging, vascular & interventional radiology, and nuclear medicine.  Lectures are provided by a distinguished group of faculty with a wealth of clinical and teaching experience, each covering the key clinical and imaging findings for differentials within common imaging gamuts, as well as characteristic “Aunt Minnie” cases.  Our goal is to provide attendees with a comprehensive gamut-based approach to image interpretation with helpful pearls to help distinguish between entities on a list of differential diagnoses.
# Visit the CME Course Webpage ›
# View the Course Brochure ›
# instructors William O’Brien, DO; Christine Glastonbury, MBBS; Jennifer McCarty, MD; Rocky Saenz, DO; Shaun Wahab, MD; Ram Chadalavada, MD; John Lichtenberger, MD; Carl Merrow, MD; Christine Chung, MD; Lori Strachowski, MD; Rifat Wahab, DO; Timothy McKnight, DO
# cme_credit Physicians:  30 Hours
# self_assessment_module Yes
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24569
# cme_course_webpage_url https://www.aocr.org/events/EventDetails.aspx?id=1616453
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 7
# Retrieving text node: id 64
# created_at 2024-01-04 10:26:21.324
# updated_at 2024-01-05 02:33:01.038
# name HN
# start_date 2024-01-05 00:26:12.846
# end_date 2024-01-05 00:26:13.998
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors HN
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 14
# event_remark
# destination_id 27
# Retrieving text node: id 59
# created_at 2024-01-04 09:38:12.491
# updated_at 2024-01-05 03:33:42.889
# name Top 3 Differentials in Radiology
# start_date 2021-11-17 00:00:00.000
# end_date 2024-08-20 00:00:00.000
# cme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States
# venue
# lat None
# lng None
# description This program is intended for practicing radiologists and radiology trainees as a comprehensive and practical case-based radiology review. All subspecialties and imaging modalities will be covered with lectures divided into the following sections: neuroimaging, musculoskeletal imaging, gastrointestinal imaging, genitourinary imaging, ultrasound imaging, cardiothoracic imaging, pediatric imaging, breast imaging, vascular & interventional radiology, and nuclear medicine. Lectures are provided by a distinguished group of faculty with a wealth of clinical and teaching experience, each covering the key clinical and imaging findings for differentials within common imaging gamuts, as well as characteristic “Aunt Minnie” cases. Our goal is to provide attendees with a comprehensive gamut-based approach to image interpretation with helpful pearls to help distinguish between entities on a list of differential diagnoses.
# Objectives:
# Formulate gamut-based differential diagnoses for key imaging findings across all radiology subspecialties and imaging modalities.
# Distinguish amongst differential diagnoses based upon characteristic imaging findings.
# Recognize & identify diagnoses with classic imaging findings, in which there is no differential diagnosis.
# Implement and optimize imaging modalities and protocols to improve diagnostic accuracy.
# Recognize appropriate indications for image-guided interventional procedures, as well as management of potential complications.
# Visit the CME Course Webpage ›
# instructors William T. O'Brien, Sr. DO, FAOCR, Program Chair
# Christopher Cerniglia, DO, ME, FAOCR
# Seetharam Chadalavada, MD, MS
# Christine M. Glastonbury, MBBS
# Grant E. Lattin, Jr., MD
# John P. Lichtenberger III, MD
# Jennifer McCarty, MD
# Timothy McKnight, DO
# Arnold Carlson Merrow, Jr., MD, FAAP
# Rocky C. Saenz, DO, FAOCR
# Lori M. Strachowski, MD
# Rifat A. Wahab, DO
# Lily Wang, MBBS
# cme_credit Physicians:  28 Hours
# self_assessment_module Yes
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24214
# cme_course_webpage_url http://aocr.mycrowdwisdom.com/diweb/catalog/item/id/6499083/q/n=4&c=476
# background_image
# price
# event_type Courses
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id None
# Retrieving text node: id 66
# created_at 2024-01-04 10:33:43.029
# updated_at 2024-01-05 02:33:02.300
# name HN
# start_date 2024-01-04 17:33:30.359
# end_date 2024-01-05 17:33:31.626
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 15
# event_remark
# destination_id 27
# Retrieving text node: id 52
# created_at 2024-01-04 09:38:12.400
# updated_at 2024-01-05 03:33:42.649
# name Multi-Modality Screening of the Breast
# start_date 2021-11-17 00:00:00.000
# end_date 2024-11-01 00:00:00.000
# cme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States
# venue
# lat None
# lng None
# description This activity is geared toward breast radiologists, general radiologists and trainees. Be ready to review key concepts in breast imaging, refresh yourself on recent updates and delve into innovations that are changing how we practice breast imaging today. Lectures are provided by a distinguished faculty who specialize in breast imaging, breast surgical oncology, or breast pathology. This diverse faculty group from various organizations have a wealth of clinical and teaching experience. Don’t miss out on this information packed course and satisfy your MQSA requirements.
# Visit the CME Course Webpage ›
# instructors Rifat Wahab, DO; Miriam David, MD; Brandy Griffith, DO; Amy Kerger, DO; Cherie Kuzmiak, DO, FACR, FSBI; Mary Mahoney, MD, FACR; Holly Marshall, MD; Amy Patel, MD; Chantal Reyna, MD, FACS, FSSO; Lauren Rosen, MD
# cme_credit Physicians:  20 Hours
# self_assessment_module Yes
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24213
# cme_course_webpage_url http://aocr.mycrowdwisdom.com/diweb/catalog/item/id/8306097/q/t=52986&c=476
# background_image
# price
# event_type Courses
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id None
# Retrieving text node: id 58
# created_at 2024-01-04 09:38:12.475
# updated_at 2024-01-05 03:33:42.863
# name Breast MRI : Comprehensive 2nd Edition
# start_date 2023-01-12 00:00:00.000
# end_date 2026-01-12 00:00:00.000
# cme_provider Efficiency Learning Systems Inc ›, Christy Lowry, PO Box 45027, Tampa, Florida (FL)  33677, United States
# venue
# lat None
# lng None
# description A concise program for the initial modality training requirement for MQSA. Includes expanded MRI case presentations with interpretation details.
# Visit the CME Course Webpage ›
# instructors Sona A. Chikarmane, MD
# Steven Harms, MD
# Azadeh Elmi, MD
# Steven Poplack, MD, FACR, FSBI
# Haydee Ojeda-Fournier, MD
# Rebecca Rakow-Penner, MD
# cme_credit Physicians:  Credit Available
# self_assessment_module No
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24646
# cme_course_webpage_url https://cme.effsystems.com/products/breast-mri-comprehensive-2nd-edition/collection
# background_image
# price
# event_type Courses
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id None
# Retrieving with query id None: 3. "Radiology conference international locations"
# Retrieving text node: id 29
# created_at 2024-01-04 09:38:10.401
# updated_at 2024-01-05 03:34:02.707
# name 2023 Top 3 Differentials in Radiology
# start_date 2023-04-24 00:00:00.000
# end_date 2023-04-28 00:00:00.000
# cme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States
# venue The Wigwam, 300 East Wigwam Blvd, Litchfield Park, Arizona (AZ), United States
# lat 33.495228
# lng -112.355125
# description The 2023 “Top 3” Conference, sponsored by the American Osteopathic College of Radiology, is intended for practicing radiologists and radiology trainees as a comprehensive and practical case-based radiology review.  All subspecialties and imaging modalities will be covered with lectures divided into the following sections: neuroimaging, musculoskeletal imaging, gastrointestinal imaging, genitourinary imaging, ultrasound imaging, cardiothoracic imaging, pediatric imaging, breast imaging, vascular & interventional radiology, and nuclear medicine.  Lectures are provided by a distinguished group of faculty with a wealth of clinical and teaching experience, each covering the key clinical and imaging findings for differentials within common imaging gamuts, as well as characteristic “Aunt Minnie” cases.  Our goal is to provide attendees with a comprehensive gamut-based approach to image interpretation with helpful pearls to help distinguish between entities on a list of differential diagnoses.
# Visit the CME Course Webpage ›
# View the Course Brochure ›
# instructors William O’Brien, DO; Christine Glastonbury, MBBS; Jennifer McCarty, MD; Rocky Saenz, DO; Shaun Wahab, MD; Ram Chadalavada, MD; John Lichtenberger, MD; Carl Merrow, MD; Christine Chung, MD; Lori Strachowski, MD; Rifat Wahab, DO; Timothy McKnight, DO
# cme_credit Physicians:  30 Hours
# self_assessment_module Yes
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24569
# cme_course_webpage_url https://www.aocr.org/events/EventDetails.aspx?id=1616453
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 7
# Retrieving text node: id 64
# created_at 2024-01-04 10:26:21.324
# updated_at 2024-01-05 02:33:01.038
# name HN
# start_date 2024-01-05 00:26:12.846
# end_date 2024-01-05 00:26:13.998
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors HN
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 14
# event_remark
# destination_id 27
# Retrieving text node: id 66
# created_at 2024-01-04 10:33:43.029
# updated_at 2024-01-05 02:33:02.300
# name HN
# start_date 2024-01-04 17:33:30.359
# end_date 2024-01-05 17:33:31.626
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 15
# event_remark
# destination_id 27
# Retrieving text node: id 59
# created_at 2024-01-04 09:38:12.491
# updated_at 2024-01-05 03:33:42.889
# name Top 3 Differentials in Radiology
# start_date 2021-11-17 00:00:00.000
# end_date 2024-08-20 00:00:00.000
# cme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States
# venue
# lat None
# lng None
# description This program is intended for practicing radiologists and radiology trainees as a comprehensive and practical case-based radiology review. All subspecialties and imaging modalities will be covered with lectures divided into the following sections: neuroimaging, musculoskeletal imaging, gastrointestinal imaging, genitourinary imaging, ultrasound imaging, cardiothoracic imaging, pediatric imaging, breast imaging, vascular & interventional radiology, and nuclear medicine. Lectures are provided by a distinguished group of faculty with a wealth of clinical and teaching experience, each covering the key clinical and imaging findings for differentials within common imaging gamuts, as well as characteristic “Aunt Minnie” cases. Our goal is to provide attendees with a comprehensive gamut-based approach to image interpretation with helpful pearls to help distinguish between entities on a list of differential diagnoses.
# Objectives:
# Formulate gamut-based differential diagnoses for key imaging findings across all radiology subspecialties and imaging modalities.
# Distinguish amongst differential diagnoses based upon characteristic imaging findings.
# Recognize & identify diagnoses with classic imaging findings, in which there is no differential diagnosis.
# Implement and optimize imaging modalities and protocols to improve diagnostic accuracy.
# Recognize appropriate indications for image-guided interventional procedures, as well as management of potential complications.
# Visit the CME Course Webpage ›
# instructors William T. O'Brien, Sr. DO, FAOCR, Program Chair
# Christopher Cerniglia, DO, ME, FAOCR
# Seetharam Chadalavada, MD, MS
# Christine M. Glastonbury, MBBS
# Grant E. Lattin, Jr., MD
# John P. Lichtenberger III, MD
# Jennifer McCarty, MD
# Timothy McKnight, DO
# Arnold Carlson Merrow, Jr., MD, FAAP
# Rocky C. Saenz, DO, FAOCR
# Lori M. Strachowski, MD
# Rifat A. Wahab, DO
# Lily Wang, MBBS
# cme_credit Physicians:  28 Hours
# self_assessment_module Yes
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24214
# cme_course_webpage_url http://aocr.mycrowdwisdom.com/diweb/catalog/item/id/6499083/q/n=4&c=476
# background_image
# price
# event_type Courses
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id None
# Retrieving text node: id 27
# created_at 2024-01-04 09:38:10.367
# updated_at 2024-01-05 03:34:02.685
# name Mayo Clinic Neuroradiology: Practice to Innovation
# start_date 2025-11-10 00:00:00.000
# end_date 2025-11-14 00:00:00.000
# cme_provider Mayo Clinic Department of Radiology ›, CME Office, 200 1st Street SW, Mayo 2-48W, Rochester, Minnesota (MN)  55905, United States
# venue Grand Hyatt Kauai Resort and Spa, 1571 Poipu Road, Koloa, Hawaii (HI), United States
# lat 21.876104
# lng -159.43938
# description Neuroradiology: Practice to Innovation is intended to provide a practical discussion and review of common diseases involving the brain, head/neck, and spine. It will also provide an overview of common imaging strategies, as well as an update in new trends, relevant techniques, and applications in diagnostic and/or therapeutic neuroradiology.
# Visit the CME Course Webpage ›
# instructors Course Directors:
# Christopher H. Hunt, M.D.
# Felix E. Diehn, M.D.
# Timothy J. Kaufmann, M.D.
# cme_credit Physicians:  Credit Available
# self_assessment_module No
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24356
# cme_course_webpage_url https://radiologyeducation.mayo.edu/store/neuroradiology-practice-to-innovation-2025
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 12
# Retrieving text node: id 23
# created_at 2024-01-04 09:38:10.272
# updated_at 2024-01-05 03:34:02.673
# name Imaging in Israel 2023
# start_date 2023-06-05 00:00:00.000
# end_date 2023-06-08 00:00:00.000
# cme_provider Global Radiology CME ›, Natalie Rice, Rochester Ave, Los Angeles, California (CA)  90024, United States
# venue Jerusalem Inbal Hotel, Ze'ev Jabotinsky St. 3, Jerusalem, Israel
# lat 32.004025
# lng 34.830276
# description Global Radiology CME in association with Hadassah Hospital Medical Center is excited to announce, Body Imager and Professor and Chair of UT Southwestern's Department of Radiology- Neil Rofsky will serve as Scientific Director for Imaging in Israel. Dr. Rofsky will be joined by the luminaries in Radiology: ? ACR's 2018 Gold Medalist and world renowned MSK imaging legend- Donald Resnick; Professor of Radiology and Director of Cardiothoracic Imaging, University of Michigan- Ella Kazerooni; and Chief of the Radiology Department at Hadassah - Jacob Sosna, as well as top local experts for cutting edge lectures at The Inbal Jerusalem Hotel.
# Ideally located a short walk from the Old City, the 5 star, luxurious Inbal Hotel, will be the conference venue. Jerusalem, is a city created by a mosaic of cultures and beliefs, where the old and new intertwine. The City of Gold is intense, engaging, and breathtakingly beautiful.
# Visit the CME Course Webpage ›
# View the Course Brochure ›
# instructors Neil Rofsky, Donald Resnick, Ella Kazerooni, Jacob Sosna
# cme_credit Physicians:  21 Hours
# self_assessment_module No
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24441
# cme_course_webpage_url https://www.globalradiologycme.com/imaginginisrael2023
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 26
# Retrieving with query id None: 4. "Radiology conference extended duration locations"
# Retrieving text node: id 29
# created_at 2024-01-04 09:38:10.401
# updated_at 2024-01-05 03:34:02.707
# name 2023 Top 3 Differentials in Radiology
# start_date 2023-04-24 00:00:00.000
# end_date 2023-04-28 00:00:00.000
# cme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States
# venue The Wigwam, 300 East Wigwam Blvd, Litchfield Park, Arizona (AZ), United States
# lat 33.495228
# lng -112.355125
# description The 2023 “Top 3” Conference, sponsored by the American Osteopathic College of Radiology, is intended for practicing radiologists and radiology trainees as a comprehensive and practical case-based radiology review.  All subspecialties and imaging modalities will be covered with lectures divided into the following sections: neuroimaging, musculoskeletal imaging, gastrointestinal imaging, genitourinary imaging, ultrasound imaging, cardiothoracic imaging, pediatric imaging, breast imaging, vascular & interventional radiology, and nuclear medicine.  Lectures are provided by a distinguished group of faculty with a wealth of clinical and teaching experience, each covering the key clinical and imaging findings for differentials within common imaging gamuts, as well as characteristic “Aunt Minnie” cases.  Our goal is to provide attendees with a comprehensive gamut-based approach to image interpretation with helpful pearls to help distinguish between entities on a list of differential diagnoses.
# Visit the CME Course Webpage ›
# View the Course Brochure ›
# instructors William O’Brien, DO; Christine Glastonbury, MBBS; Jennifer McCarty, MD; Rocky Saenz, DO; Shaun Wahab, MD; Ram Chadalavada, MD; John Lichtenberger, MD; Carl Merrow, MD; Christine Chung, MD; Lori Strachowski, MD; Rifat Wahab, DO; Timothy McKnight, DO
# cme_credit Physicians:  30 Hours
# self_assessment_module Yes
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24569
# cme_course_webpage_url https://www.aocr.org/events/EventDetails.aspx?id=1616453
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 7
# Retrieving text node: id 64
# created_at 2024-01-04 10:26:21.324
# updated_at 2024-01-05 02:33:01.038
# name HN
# start_date 2024-01-05 00:26:12.846
# end_date 2024-01-05 00:26:13.998
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors HN
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 14
# event_remark
# destination_id 27
# Retrieving text node: id 66
# created_at 2024-01-04 10:33:43.029
# updated_at 2024-01-05 02:33:02.300
# name HN
# start_date 2024-01-04 17:33:30.359
# end_date 2024-01-05 17:33:31.626
# cme_provider HN
# venue Hanoi, Vietnam
# lat 21.030384
# lng 105.85531
# description
# instructors
# cme_credit
# self_assessment_module
# crawl_url
# cme_course_webpage_url
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field
# points 15
# event_remark
# destination_id 27
# Retrieving text node: id 16
# created_at 2024-01-04 09:38:05.515
# updated_at 2024-01-05 03:33:54.727
# name 9th Annual Lung Cancer Symposium - Virtual Meeting
# start_date 2021-03-04 00:00:00.000
# end_date 2021-03-05 00:00:00.000
# cme_provider Thomas Jefferson University ›, Office of Continuing Professional Development, 1020 Locust Street, Philadelphia, Pennsylvania (PA)  19107, United States
# venue
# lat None
# lng None
# description The 9th Annual Lung Cancer Symposium will offer attendees the opportunity for a comprehensive update in lung cancer while interacting with our state of the art faculty and reviewing actual cases with a mock tumor board.
# Topics will include lung cancer screening, a surgical approach to early stage disease, and evolving therapeutics for advanced stage, metastatic or recurrent disease.  The course is designed for physicians, physicians assistance, nurses, nurse practitioners, social workers, respiratory therapists, and public health professionals.  Available tracks will allow the learner to focus on those aspects of lung cancer which are of greatest interest.
# NEW THIS YEAR! Optional Pre-Conference Modules for extra CE credits!
# Visit the CME Course Webpage ›
# instructors Kane, Wener Wasik, Barta, Unger, Evans, Myers, Shusted, Giamboy, LaCoutre
# cme_credit Physicians:  12.25 Hours
# Physician Assistants:  12.25 Hours
# Nurses:  12.30 Hours
# self_assessment_module No
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=23412
# cme_course_webpage_url https://cme.jefferson.edu/content/lung2021
# background_image
# price
# event_type Webinars
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiation Therapist
# points None
# event_remark
# destination_id None
# Retrieving text node: id 22
# created_at 2024-01-04 09:38:10.271
# updated_at 2024-01-05 03:34:02.671
# name Advanced Imaging In the Islands
# start_date 2024-02-20 00:00:00.000
# end_date 2024-02-23 00:00:00.000
# cme_provider Duke University Department of Radiology ›, Debbie Griffin, Room 1531B Duke University Hospital, 2301 Erwin Road, Durham, North Carolina (NC)  27710, United States
# venue The Ritz-Carlton, Grand Cayman, PO Box 32348 KY1-1209, Seven Mile Beach, Grand Cayman, Cayman Islands
# lat 26.8917
# lng -80.08965
# description This course has been designed for the
# radiologist interested in gaining a greater
# understanding of advances in diagnostic
# imaging, specifically implementing a
# multidisciplinary approach to education
# via a combination of experts from
# Duke’s Divisions of Abdominal Imaging
# Breast Imaging, Cardiothoracic Imaging,
# Neuroradiology, Musculoskeletal Imaging
# and Vascular/Interventional Radiology.
# Visit the CME Course Webpage ›
# View the Course Brochure ›
# instructors Rajan Gupta, MD
# Professor
# Travis Henry, MD
# Professor
# Lisa Ho, MD
# Associate Professor
# Peter Kranz, MD
# Associate Professor
# Paul Suhocki, MD
# Associate Professor
# Leah Waldman, MD
# Assistant Professor
# cme_credit Physicians:  20 Hours
# Physician Assistants:  20 Hours
# self_assessment_module No
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24688
# cme_course_webpage_url https://radiology.duke.edu/education/continuing-medical-education/advanced-imaging-islands-feb-20-23-2024
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 5
# Retrieving text node: id 27
# created_at 2024-01-04 09:38:10.367
# updated_at 2024-01-05 03:34:02.685
# name Mayo Clinic Neuroradiology: Practice to Innovation
# start_date 2025-11-10 00:00:00.000
# end_date 2025-11-14 00:00:00.000
# cme_provider Mayo Clinic Department of Radiology ›, CME Office, 200 1st Street SW, Mayo 2-48W, Rochester, Minnesota (MN)  55905, United States
# venue Grand Hyatt Kauai Resort and Spa, 1571 Poipu Road, Koloa, Hawaii (HI), United States
# lat 21.876104
# lng -159.43938
# description Neuroradiology: Practice to Innovation is intended to provide a practical discussion and review of common diseases involving the brain, head/neck, and spine. It will also provide an overview of common imaging strategies, as well as an update in new trends, relevant techniques, and applications in diagnostic and/or therapeutic neuroradiology.
# Visit the CME Course Webpage ›
# instructors Course Directors:
# Christopher H. Hunt, M.D.
# Felix E. Diehn, M.D.
# Timothy J. Kaufmann, M.D.
# cme_credit Physicians:  Credit Available
# self_assessment_module No
# crawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24356
# cme_course_webpage_url https://radiologyeducation.mayo.edu/store/neuroradiology-practice-to-innovation-2025
# background_image
# price
# event_type On-site meeting
# is_edited False
# need_map_data False
# status ACCEPTED
# medical_field Radiology
# points None
# event_remark
# destination_id 12

# %%
print(response.get_formatted_sources())
# Out:
# > Source (Node id: beef315e-56e6-4efa-8876-5a42cc246500): id 29
# created_at 2024-01-04 09:38:10.401
# updated_at 2024-01-05 03:34:02.707
# name 2023 Top 3 Diffe...
#
# > Source (Node id: 7c0b09a9-e0b3-41dc-94d8-532ce7ae1344): id 64
# created_at 2024-01-04 10:26:21.324
# updated_at 2024-01-05 02:33:01.038
# name HN
# start_date 20...
#
# > Source (Node id: dfa5270d-00b5-4731-a416-2622961501ce): id 59
# created_at 2024-01-04 09:38:12.491
# updated_at 2024-01-05 03:33:42.889
# name Top 3 Differenti...
#
# > Source (Node id: 44967a0d-f90d-4a02-9220-377758c68bb9): id 66
# created_at 2024-01-04 10:33:43.029
# updated_at 2024-01-05 02:33:02.300
# name HN
# start_date 20...
#
# > Source (Node id: bc557a50-bafd-43bd-8957-57ea2daa8196): id 22
# created_at 2024-01-04 09:38:10.271
# updated_at 2024-01-05 03:34:02.671
# name Advanced Imaging...
#
# > Source (Node id: 8f349db8-7814-4a96-a593-98de715af3be): id 52
# created_at 2024-01-04 09:38:12.400
# updated_at 2024-01-05 03:33:42.649
# name Multi-Modality S...

# %%
response.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='beef315e-56e6-4efa-8876-5a42cc246500', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='9452773b-7968-4eb4-8d8c-2885dab2b221', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='edf2a299ed718a9228d10dfdfb2402099d73a833076e27cf3609075efd38d910'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='68144552-a0b9-4971-a50d-89cbef1f0290', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='ac5b891f5452785563ce3a891b8317fbc1b31067ba63c7d48c66e6c03f14323a')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text='id 29\ncreated_at 2024-01-04 09:38:10.401\nupdated_at 2024-01-05 03:34:02.707\nname 2023 Top 3 Differentials in Radiology\nstart_date 2023-04-24 00:00:00.000\nend_date 2023-04-28 00:00:00.000\ncme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States\nvenue The Wigwam, 300 East Wigwam Blvd, Litchfield Park, Arizona (AZ), United States\nlat 33.495228\nlng -112.355125\ndescription The 2023 “Top 3” Conference, sponsored by the American Osteopathic College of Radiology, is intended for practicing radiologists and radiology trainees as a comprehensive and practical case-based radiology review.  All subspecialties and imaging modalities will be covered with lectures divided into the following sections: neuroimaging, musculoskeletal imaging, gastrointestinal imaging, genitourinary imaging, ultrasound imaging, cardiothoracic imaging, pediatric imaging, breast imaging, vascular & interventional radiology, and nuclear medicine.  Lectures are provided by a distinguished group of faculty with a wealth of clinical and teaching experience, each covering the key clinical and imaging findings for differentials within common imaging gamuts, as well as characteristic “Aunt Minnie” cases.  Our goal is to provide attendees with a comprehensive gamut-based approach to image interpretation with helpful pearls to help distinguish between entities on a list of differential diagnoses.\nVisit the CME Course Webpage ›\nView the Course Brochure ›\ninstructors William O’Brien, DO; Christine Glastonbury, MBBS; Jennifer McCarty, MD; Rocky Saenz, DO; Shaun Wahab, MD; Ram Chadalavada, MD; John Lichtenberger, MD; Carl Merrow, MD; Christine Chung, MD; Lori Strachowski, MD; Rifat Wahab, DO; Timothy McKnight, DO\ncme_credit Physicians:  30 Hours\nself_assessment_module Yes\ncrawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24569\ncme_course_webpage_url https://www.aocr.org/events/EventDetails.aspx?id=1616453\nbackground_image \nprice \nevent_type On-site meeting\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field Radiology\npoints None\nevent_remark \ndestination_id 7', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.016666666666666666),
#  NodeWithScore(node=TextNode(id_='7c0b09a9-e0b3-41dc-94d8-532ce7ae1344', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='fb48f079-a169-4ea9-9108-382e6cbd3761', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='4d638fd299a52438470f6946a6b9169319c14aaee8e017650008e236757150e9'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='44967a0d-f90d-4a02-9220-377758c68bb9', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='8b61eebcc4204893d123fc3ef92433ab455a240b9def81f867f92b4a96965172')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text='id 64\ncreated_at 2024-01-04 10:26:21.324\nupdated_at 2024-01-05 02:33:01.038\nname HN\nstart_date 2024-01-05 00:26:12.846\nend_date 2024-01-05 00:26:13.998\ncme_provider HN\nvenue Hanoi, Vietnam\nlat 21.030384\nlng 105.85531\ndescription \ninstructors HN\ncme_credit \nself_assessment_module \ncrawl_url \ncme_course_webpage_url \nbackground_image \nprice \nevent_type On-site meeting\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field \npoints 14\nevent_remark \ndestination_id 27', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.01639344262295082),
#  NodeWithScore(node=TextNode(id_='dfa5270d-00b5-4731-a416-2622961501ce', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='b54dfa26-795f-47f8-9e43-c48e06b04f59', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='d79c2ec4cc0d1d2e9385180b504db40929143439264d0d2ac36db63828490bbc'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='d2308e05-3489-406c-ae0c-6b2cc329ab63', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='ee21a14393d5e3046ced738ba0c1bf3addae8fa11d2cb6bfe2d892c58e064f9c')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text="id 59\ncreated_at 2024-01-04 09:38:12.491\nupdated_at 2024-01-05 03:33:42.889\nname Top 3 Differentials in Radiology\nstart_date 2021-11-17 00:00:00.000\nend_date 2024-08-20 00:00:00.000\ncme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States\nvenue \nlat None\nlng None\ndescription This program is intended for practicing radiologists and radiology trainees as a comprehensive and practical case-based radiology review. All subspecialties and imaging modalities will be covered with lectures divided into the following sections: neuroimaging, musculoskeletal imaging, gastrointestinal imaging, genitourinary imaging, ultrasound imaging, cardiothoracic imaging, pediatric imaging, breast imaging, vascular & interventional radiology, and nuclear medicine. Lectures are provided by a distinguished group of faculty with a wealth of clinical and teaching experience, each covering the key clinical and imaging findings for differentials within common imaging gamuts, as well as characteristic “Aunt Minnie” cases. Our goal is to provide attendees with a comprehensive gamut-based approach to image interpretation with helpful pearls to help distinguish between entities on a list of differential diagnoses.\nObjectives:\nFormulate gamut-based differential diagnoses for key imaging findings across all radiology subspecialties and imaging modalities.\nDistinguish amongst differential diagnoses based upon characteristic imaging findings.\nRecognize & identify diagnoses with classic imaging findings, in which there is no differential diagnosis.\nImplement and optimize imaging modalities and protocols to improve diagnostic accuracy.\nRecognize appropriate indications for image-guided interventional procedures, as well as management of potential complications.\nVisit the CME Course Webpage ›\ninstructors William T. O'Brien, Sr. DO, FAOCR, Program Chair\nChristopher Cerniglia, DO, ME, FAOCR\nSeetharam Chadalavada, MD, MS\nChristine M. Glastonbury, MBBS\nGrant E. Lattin, Jr., MD\nJohn P. Lichtenberger III, MD\nJennifer McCarty, MD\nTimothy McKnight, DO\nArnold Carlson Merrow, Jr., MD, FAAP\nRocky C. Saenz, DO, FAOCR\nLori M. Strachowski, MD\nRifat A. Wahab, DO\nLily Wang, MBBS\ncme_credit Physicians:  28 Hours\nself_assessment_module Yes\ncrawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24214\ncme_course_webpage_url http://aocr.mycrowdwisdom.com/diweb/catalog/item/id/6499083/q/n=4&c=476\nbackground_image \nprice \nevent_type Courses\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field Radiology\npoints None\nevent_remark \ndestination_id None", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.016129032258064516),
#  NodeWithScore(node=TextNode(id_='44967a0d-f90d-4a02-9220-377758c68bb9', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='7c0b09a9-e0b3-41dc-94d8-532ce7ae1344', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='0b068904257463179c6cd95f1216b4e2fcf03f0d1479dc4109e8434a4fdb07a8'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='4868e533-ccc9-47b6-bbc9-89e91c7baa9a', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='3d4284c91d7bf9f76e98e8505d54b5e7802cef2abc81f3befe7fc2c41d986d73')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text='id 66\ncreated_at 2024-01-04 10:33:43.029\nupdated_at 2024-01-05 02:33:02.300\nname HN\nstart_date 2024-01-04 17:33:30.359\nend_date 2024-01-05 17:33:31.626\ncme_provider HN\nvenue Hanoi, Vietnam\nlat 21.030384\nlng 105.85531\ndescription \ninstructors \ncme_credit \nself_assessment_module \ncrawl_url \ncme_course_webpage_url \nbackground_image \nprice \nevent_type On-site meeting\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field \npoints 15\nevent_remark \ndestination_id 27', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.015873015873015872),
#  NodeWithScore(node=TextNode(id_='bc557a50-bafd-43bd-8957-57ea2daa8196', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='41256943-f228-4c49-a590-1cda02eda4ad', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='29941b6003bda96047a17b5b193a0566e6a86ca41496c84e93176ce65bca0559'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='fb48f079-a169-4ea9-9108-382e6cbd3761', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='4d638fd299a52438470f6946a6b9169319c14aaee8e017650008e236757150e9')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text='id 22\ncreated_at 2024-01-04 09:38:10.271\nupdated_at 2024-01-05 03:34:02.671\nname Advanced Imaging In the Islands\nstart_date 2024-02-20 00:00:00.000\nend_date 2024-02-23 00:00:00.000\ncme_provider Duke University Department of Radiology ›, Debbie Griffin, Room 1531B Duke University Hospital, 2301 Erwin Road, Durham, North Carolina (NC)  27710, United States\nvenue The Ritz-Carlton, Grand Cayman, PO Box 32348 KY1-1209, Seven Mile Beach, Grand Cayman, Cayman Islands\nlat 26.8917\nlng -80.08965\ndescription This course has been designed for the\nradiologist interested in gaining a greater\nunderstanding of advances in diagnostic\nimaging, specifically implementing a\nmultidisciplinary approach to education\nvia a combination of experts from\nDuke’s Divisions of Abdominal Imaging\nBreast Imaging, Cardiothoracic Imaging,\nNeuroradiology, Musculoskeletal Imaging\nand Vascular/Interventional Radiology.\nVisit the CME Course Webpage ›\nView the Course Brochure ›\ninstructors Rajan Gupta, MD\nProfessor\nTravis Henry, MD\nProfessor\nLisa Ho, MD\nAssociate Professor\nPeter Kranz, MD\nAssociate Professor\nPaul Suhocki, MD\nAssociate Professor\nLeah Waldman, MD\nAssistant Professor\ncme_credit Physicians:  20 Hours\nPhysician Assistants:  20 Hours\nself_assessment_module No\ncrawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24688\ncme_course_webpage_url https://radiology.duke.edu/education/continuing-medical-education/advanced-imaging-islands-feb-20-23-2024\nbackground_image \nprice \nevent_type On-site meeting\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field Radiology\npoints None\nevent_remark \ndestination_id 5', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.015873015873015872),
#  NodeWithScore(node=TextNode(id_='8f349db8-7814-4a96-a593-98de715af3be', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='695115fa-f15d-473b-ac4d-d4eab50fde25', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='5571456d8fc3dc1b96829f28768de1d98de62cf74e8cff6805554ddf8521ce7e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='3131a7a8-8a7a-48f4-8353-f74e425263fe', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='be9aef42439afc64ea2a654e9e4bb9f3d8035508b61e998495330a1c2d7c91f1'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='0e3b21d6-fc98-4936-82b1-abadd5b8f621', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='f397e15b833510b9d8fc3fc94a3b109bbff57a10108035f9a6aa96acb0928daf')}, hash='44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a', text='id 52\ncreated_at 2024-01-04 09:38:12.400\nupdated_at 2024-01-05 03:33:42.649\nname Multi-Modality Screening of the Breast\nstart_date 2021-11-17 00:00:00.000\nend_date 2024-11-01 00:00:00.000\ncme_provider American Osteopathic College of Radiology ›, 119 East Second Street, Milan, Missouri (MO)  63556-4011, United States\nvenue \nlat None\nlng None\ndescription This activity is geared toward breast radiologists, general radiologists and trainees. Be ready to review key concepts in breast imaging, refresh yourself on recent updates and delve into innovations that are changing how we practice breast imaging today. Lectures are provided by a distinguished faculty who specialize in breast imaging, breast surgical oncology, or breast pathology. This diverse faculty group from various organizations have a wealth of clinical and teaching experience. Don’t miss out on this information packed course and satisfy your MQSA requirements.\nVisit the CME Course Webpage ›\ninstructors Rifat Wahab, DO; Miriam David, MD; Brandy Griffith, DO; Amy Kerger, DO; Cherie Kuzmiak, DO, FACR, FSBI; Mary Mahoney, MD, FACR; Holly Marshall, MD; Amy Patel, MD; Chantal Reyna, MD, FACS, FSSO; Lauren Rosen, MD\ncme_credit Physicians:  20 Hours\nself_assessment_module Yes\ncrawl_url http://www.radlist.com//PubCMEDetails.aspx?id=24213\ncme_course_webpage_url http://aocr.mycrowdwisdom.com/diweb/catalog/item/id/8306097/q/t=52986&c=476\nbackground_image \nprice \nevent_type Courses\nis_edited False\nneed_map_data False\nstatus ACCEPTED\nmedical_field Radiology\npoints None\nevent_remark \ndestination_id None', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.015625)]

# %%
response.print_response_stream()
# Out:
# [22]
